# %% [markdown]
# #### Bag of Words

# %%
import pandas as pd
messages = pd.read_csv('data/bag_of_words.csv', sep=',', names=['label', 'message'])
messages.head()
# Out:
#     label                                            message
# id  label                                            message
# 1    spam  Congratulations you have won a free lottery ti...
# 2     ham                 Hey are we meeting for lunch today
# 3    spam           Claim your free prize now click the link
# 4     ham                 Please review the project document

# %% [markdown]
# #### Data cleaning and processing

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
    review = review.lower()
    review = review.split()
    
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4352\3029823152.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])

# %%
corpus
# Out:
# ['messag',
#  'congratul free lotteri ticket',
#  'hey meet lunch today',
#  'claim free prize click link',
#  'pleas review project document',
#  'limit time offer buy get discount',
#  'send meet note',
#  'win cash reward instantli regist',
#  'call even',
#  'exclus deal click',
#  'let us schedul team meet tomorrow',
#  'get cheap medicin without prescript',
#  'happi birthday wonder day',
#  'select free vacat',
#  'pleas find attach report',
#  'earn money quickli home',
#  'finish code task',
#  'urgent respond claim reward',
#  'let know avail',
#  'special promot get percent',
#  'server deploy complet',
#  'click link verifi account',
#  'thank help yesterday',
#  'lucki winner claim',
#  'discuss tomorrow meet',
#  'free entri contest win big prize',
#  'review code chang',
#  'lowest price guarante shop today',
#  'dinner plan tonight',
#  'act secur bonu',
#  'project deadlin next monday']

# %% [markdown]
# #### Create Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500)
X = cv.fit_transform(corpus).toarray()
X.shape
# Out:
# (31, 94)
